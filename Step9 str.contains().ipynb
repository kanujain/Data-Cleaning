# %%
import pandas as pd

data = pd.read_csv("E:\\2020\\Quarantine\\Python\\collection-master\\artwork_data.csv",low_memory=False)
data.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
data.medium
# Out:
# 0        Watercolour, ink, chalk and graphite on paper....
# 1                                        Graphite on paper
# 2              Graphite on paper. Verso: graphite on paper
# 3                                        Graphite on paper
# 4                                  Line engraving on paper
#                                ...
# 69196     Perspex, Wood, hairpiece, tampon and human blood
# 69197    Wood, Perspex, plastic, photograph on paper, t...
# 69198                                 Soap and glass beads
# 69199                                     Gallery lighting
# 69200                                  Oil paint on canvas
# Name: medium, Length: 69201, dtype: object

# %%
type(data.medium)
# Out:
# pandas.core.series.Series

# %%
data.medium.str

# %%
data.medium.str.contains('Graphite')
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 69196    False
# 69197    False
# 69198    False
# 69199    False
# 69200    False
# Name: medium, Length: 69201, dtype: object

# %%
address = pd.to_numeric(data.medium.str.contains('Graphite'), errors = "coerce")
address
# Out:
# 0        0.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        0.0
#         ...
# 69196    0.0
# 69197    0.0
# 69198    0.0
# 69199    0.0
# 69200    0.0
# Name: medium, Length: 69201, dtype: float64

# %%
data.medium.str.contains('Graphite')
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 69196    False
# 69197    False
# 69198    False
# 69199    False
# 69200    False
# Name: medium, Length: 69201, dtype: object

# %%
data.loc[data.medium.str.contains('Graphite'), :]
# Out:
#          id accession_number         artist artistRole  artistId  \
# 0.0  1035.0           A00001  Blake, Robert     artist      38.0
# 1.0  1036.0           A00002  Blake, Robert     artist      38.0
# 1.0  1036.0           A00002  Blake, Robert     artist      38.0
# 1.0  1036.0           A00002  Blake, Robert     artist      38.0
# 0.0  1035.0           A00001  Blake, Robert     artist      38.0
#
#                                                  title        dateText  \
# 0.0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1.0  Two Drawings of Frightened Figures, Probably f...  date not known
# 1.0  Two Drawings of Frightened Figures, Probably f...  date not known
# 1.0  Two Drawings of Frightened Figures, Probably f...  date not known
# 0.0  A Figure Bowing before a Seated Old Man with h...  date not known
#
#                                                 medium  \
# 0.0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
data.loc[data.medium.str.contains('Graphite|line', regex = True, na = False), :]

# %%
data.loc[data.medium.str.contains('(?i)Graphite|line', regex = True, na = False), :]  # for case sensitivity

# %%
data.loc[data.year.astype(str).str.contains('1826', na = False), : ] #

# %%
data.loc[data.acquisitionYear.filter(regex = '19^'), : ]    'X' Wrong as 
                                            'data.acquisitionYear.filter(regex = ''19^')'
# Out:
# Empty DataFrame
# Columns: [id, accession_number, artist, artistRole, artistId, title, dateText, medium, creditLine, year, acquisitionYear, dimensions, width, height, depth, units, inscription, thumbnailCopyright, thumbnailUrl, url]
# Index: []
