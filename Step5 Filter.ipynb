# %%
import pandas as pd

# %%
data = pd.read_csv("E:\\2020\\Quarantine\\Python\\collection-master\\artwork_data.csv",low_memory=False)
data.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
data.filter(items= ['id', 'artist', 'acquisitionYear']) #Collecting required columns
# Out:
#            id              artist  acquisitionYear
# 0        1035       Blake, Robert           1922.0
# 1        1036       Blake, Robert           1922.0
# 2        1037       Blake, Robert           1922.0
# 3        1038       Blake, Robert           1922.0
# 4        1039      Blake, William           1919.0
# ...       ...                 ...              ...
# 69196  122960  P-Orridge, Genesis           2013.0
# 69197  122961  P-Orridge, Genesis           2013.0
# 69198  121181        Hatoum, Mona           2013.0
# 69199  112306       Creed, Martin           2013.0
# 69200  127035   Brunias, Agostino           2013.0
#
# [69201 rows x 3 columns]

# %%
#Like function is case sensitive

data.filter(like = 'year')
# Out:
#        year
# 0       NaN
# 1       NaN
# 2      1785
# 3       NaN
# 4      1826
# ...     ...
# 69196  1975
# 69197  1976
# 69198  1996
# 69199  2000
# 69200  1764
#
# [69201 rows x 1 columns]

# %%
data.filter(like = 'artist')
# Out:
#                    artist artistRole  artistId
# 0           Blake, Robert     artist        38
# 1           Blake, Robert     artist        38
# 2           Blake, Robert     artist        38
# 3           Blake, Robert     artist        38
# 4          Blake, William     artist        39
# ...                   ...        ...       ...
# 69196  P-Orridge, Genesis     artist     16646
# 69197  P-Orridge, Genesis     artist     16646
# 69198        Hatoum, Mona     artist      2365
# 69199       Creed, Martin     artist      2760
# 69200   Brunias, Agostino     artist      3824
#
# [69201 rows x 3 columns]

# %%
#We can use regular expression to display

# %%
data.filter(regex = '(?i)year')  #ignoring case sensitivity
# Out:
#        year  acquisitionYear
# 0       NaN           1922.0
# 1       NaN           1922.0
# 2      1785           1922.0
# 3       NaN           1922.0
# 4      1826           1919.0
# ...     ...              ...
# 69196  1975           2013.0
# 69197  1976           2013.0
# 69198  1996           2013.0
# 69199  2000           2013.0
# 69200  1764           2013.0
#
# [69201 rows x 2 columns]

# %%
p = pd.DataFrame(['1a2ajnjwef3yguj423yugbdwi999', 234, 'asdf'])

# %%
p.filter(regex="[a-z]")  #charahter containing []
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]

# %%
p.filter(regex="^2.$")
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]

# %%
data.filter(axis=0, regex= '^100.$')  #Starting with 100_ and ending with anythinhg
# Out:
#          id accession_number                          artist artistRole  \
# 1000  14704           A01004  Turner, Joseph Mallord William     artist
# 1001  14705           A01005  Turner, Joseph Mallord William     artist
# 1002  14706           A01006  Turner, Joseph Mallord William     artist
# 1003  14707           A01007  Turner, Joseph Mallord William     artist
# 1004  14708           A01008  Turner, Joseph Mallord William     artist
# 1005  14709           A01009  Turner, Joseph Mallord William     artist
# 1006  14710           A01010  Turner, Joseph Mallord William     artist
# 1007  14711           A01011  Turner, Joseph Mallord William     artist
# 1008  14712           A01012  Turner, Joseph Mallord William     artist
# 1009  14713           A01013  Turner, Joseph Mallord William     artist
#
#       artistId                                              title dateText  \
# 1000       558                               Hedging and Ditching     1812
# ...

# %%
data.filter(axis=0, regex = '^100.(2|4|6|8)$')  #only even values
# Out:
#           id accession_number                          artist artistRole  \
# 10002  34544           D07155  Turner, Joseph Mallord William     artist
# 10004  34546           D07157  Turner, Joseph Mallord William     artist
# 10006  34548           D07159  Turner, Joseph Mallord William     artist
# 10008  34550           D07161  Turner, Joseph Mallord William     artist
# 10012  34554           D07165  Turner, Joseph Mallord William     artist
# 10014  34556           D07167  Turner, Joseph Mallord William     artist
# 10016  34558           D07169  Turner, Joseph Mallord William     artist
# 10018  34560           D07171  Turner, Joseph Mallord William     artist
# 10022  34564           D07175  Turner, Joseph Mallord William     artist
# 10024  34566           D07177  Turner, Joseph Mallord William     artist
# 10026  34568           D07179  Turner, Joseph Mallord William     artist
# 10028  34570           D07181  Turner, Joseph Mallord William     artist
# ...
